# %%
# import necessary libraries
import os
import logging
from pathlib import Path
from time import sleep
from typing import List

import numpy as np
import pandas as pd
import openai
from sklearn.metrics import accuracy_score

from capstone.config import CapstoneConfig
from capstone.data_access import DataClass

openai.api_key = os.getenv("OPENAI_API_KEY")
PARENT_PATH = Path(os.getcwd()).parent.absolute()
FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)

# %%
config = CapstoneConfig()
config.CURRENT_PATH = PARENT_PATH

data = DataClass(config)

# %%
openai.FineTune.list()
# Out:
# 2022-11-02 19:13:19,939 - openai - INFO - message='Request to OpenAI API' method=get path=https://api.openai.com/v1/fine-tunes
# 2022-11-02 19:13:20,245 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/fine-tunes processing_ms=60 request_id=e12d9051ca4aff46347b012bbe55010f response_code=200
# <OpenAIObject list at 0x11321cae0> JSON: {
#   "data": [
#     {
#       "created_at": 1667170020,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-BrsXzlDOnXIlOKBmEPaTAOll",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-aMHEQTPYWIZZ6Kcb2h4CPN3I",
#       "result_files": [],
#       "status": "cancelled",
#       "training_files": [
#         {
#           "bytes": 371730,
#           "created_at": 1667167174,
#           "filename": "jnj_hygiene_ft_training_data_prepared.jsonl",
#           "id": "file-MY2MYiaLnqqbysIfzO7dOopR",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1667170251,
#       "validation_files": []
#     },
#     {
#       "created_at": 1667173177,
#       "fine_tuned_model": "davinci:ft-columbia-capstone-jnj:davinci-hygiene-ft-2022-10-31-00-51-43",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-ayapkwFiOzuuvAIlqcjOTLJM",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-aMHEQTPYWIZZ6Kcb2h4CPN3I",
#       "result_files": [
#         {
#           "bytes": 146660,
#           "created_at": 1667177505,
#           "filename": "compiled_results.csv",
#           "id": "file-vLPpfijkboD2NfnW59nvphWH",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 371730,
#           "created_at": 1667167174,
#           "filename": "jnj_hygiene_ft_training_data_prepared.jsonl",
#           "id": "file-MY2MYiaLnqqbysIfzO7dOopR",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1667177506,
#       "validation_files": []
#     },
#     {
#       "created_at": 1667415375,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-btK0Q2qJQ9cQ9rpaZyNuAvxf",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-aMHEQTPYWIZZ6Kcb2h4CPN3I",
#       "result_files": [],
#       "status": "cancelled",
#       "training_files": [
#         {
#           "bytes": 4579,
#           "created_at": 1667414911,
#           "filename": "file",
#           "id": "file-2cRGejWxkYCCcgGzFmKqQvxU",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1667421724,
#       "validation_files": []
#     },
#     {
#       "created_at": 1667415675,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": null,
#         "learning_rate_multiplier": null,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-GZeGtMZxBwRbZ7E4i5OX22hx",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-aMHEQTPYWIZZ6Kcb2h4CPN3I",
#       "result_files": [],
#       "status": "cancelled",
#       "training_files": [
#         {
#           "bytes": 4579,
#           "created_at": 1667414911,
#           "filename": "file",
#           "id": "file-2cRGejWxkYCCcgGzFmKqQvxU",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1667420547,
#       "validation_files": []
#     },
#     {
#       "created_at": 1667426536,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-8GVq4UkdNIK9aMC7XsEmCpsv",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-aMHEQTPYWIZZ6Kcb2h4CPN3I",
#       "result_files": [],
#       "status": "pending",
#       "training_files": [
#         {
#           "bytes": 56549,
#           "created_at": 1667425332,
#           "filename": "out1.jsonl",
#           "id": "file-U1dtLdksi0ZTWFWATOZjFjpZ",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1667430578,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %%
# Useful constants
MODEL = "davinci:ft-columbia-capstone-jnj:davinci-hygiene-ft-2022-10-31-00-51-43"
TEXT = "text"
TARGET = "completion"
PREDICTED = "category"
PROBAB = "probability"

# %%
# read in test set
df1 = pd.read_csv(os.path.join(data.data_path, "eudralex_chapter4_documentation.csv"))
df1.head(2)
# Out:
#            Level 1 - Header  \
# 0  Chapter 4: Documentation
# 1  Chapter 4: Documentation
#
#                                  Level 1 - Paragraph  \
# 0  Legal basis for publishing the detailed guidel...
# 1  Legal basis for publishing the detailed guidel...
#
#                           Level 2 - Header Level 2 - Body Level 3 - Header  \
# 0  Generation and Control of Documentation            NaN              4.1
# 1  Generation and Control of Documentation            NaN              4.2
#
#                                       Level 3 - Body  Level 4 - Header  \
# 0  All types of document should be defined and ad...               NaN
# 1  Documents should be designed, prepared, review...               NaN
#
#   Level 4 - Body                                               text  \
# 0            NaN  All types of document should be defined and ad...
# 1            NaN  Documents should be designed, prepared, review...
#
#                                               prompt completion
# 0  All types of document should be defined and ad...      other
# 1  Documents should be designed, prepared, review...      other

# %%
# function to predict the categories from the test set; input relevant engine name
def get_category(text):
    sleep(5)                                               # trottle for rate limit
    response = openai.Completion.create(
            prompt=f"Text: {text}\nCategory:",
            temperature=0,
            max_tokens=1,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            model=MODEL,  #"RegulatoryStandardsClassifier2" is the ft-engine in our internal Azure OpenAI, use text-davinci-002 on the free tier. 
            logprobs=2
            #logit_bias={"584":100, "33306":100}
        )
    #return (response["choices"][0])
    return (response["choices"][0]["text"])

# function to extract the probability of categorical response; input relevant engine name
def get_prob(text):
    sleep(5)                                               # trottle for rate limit
    response = openai.Completion.create(
            prompt=f"Text: {text}\nCategory:",
            temperature=0,
            max_tokens=1,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            model=MODEL, #"RegulatoryStandardsClassifier2" is the ft-engine in our internal Azure OpenAI, use text-davinci-002 on the free tier. 
            logprobs=2
            #logit_bias={"584":100, "33306":100}
        )
    #return (response["choices"][0])
    return (np.exp(response["choices"][0]["logprobs"]["top_logprobs"][0][get_category(text)]))

# %%
# predict category and extract probability of each cateogorical response for the test set
df1['category'] = df1.text.apply(get_category)
df1['probability'] = df1.text.apply(get_prob)
# Out:
# 2022-11-02 19:18:21,158 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-02 19
- openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=74 request_id=2cd73c4b25fd7a4d43afd0c83df34770 response_code=200
# 2022-11-02 19:26:34,905 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-02 19:26:35,024 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=56 request_id=0e56eeb6c582e7afe0f9837a4cd9399b response_code=200

# %%
list(df1['prompt'][25:35])
# Out:
# ['There should be written procedures for testing materials and products at different stages of manufacture, describing the methods and equipment to be used. The tests performed should be recorded.',
#  'Written release and rejection procedures should be available for materials and products, and in particular for the certification for sale of the finished product by the Qualified Person(s). All records should be available to the Qualified Person. A system should be in place to indicate special observations and any changes to critical data.',
#  'Records should be maintained for the distribution of each batch of a product in order to facilitate recall of any batch, if necessary.',
#  'There should be written policies, procedures, protocols, reports and the associated records of actions taken or conclusions reached, where appropriate, for the following examples:/nValidation and qualification of processes, equipment and systems;/nEquipment assembly and calibration;/nTechnology transfer;/nMaintenance, cleaning and sanitation;/nPersonnel matters including signature lists, training in GMP and technical matters, clothing and hygiene and verification of the effectiveness of training./nEnvironmental monitoring;/nPest control;/nComplaints;/nRecalls;/nReturns;/nChange control;/nInvestigations into deviations and non-conformances;/nInternal quality/GMP compliance audits;/nSummaries of records where appropriate (e.g. product quality review);/nSupplier audits.',
#  'Clear operating procedures should be available for major items of manufacturing and test equipment.',
#  'Logbooks should be kept for major or critical analytical testing, production equipment, and areas where product has been processed. They should be used to record in chronological order, as appropriate, any use of the area, equipment/method, calibrations, maintenance, cleaning or repair operations, including the dates and identity of people who carried these operations out.',
#  'An inventory of documents within the Quality Management System should be maintained.']

# %%
df1.head(2)
# Out:
#            Level 1 - Header  \
# 0  Chapter 4: Documentation
# 1  Chapter 4: Documentation
#
#                                  Level 1 - Paragraph  \
# 0  Legal basis for publishing the detailed guidel...
# 1  Legal basis for publishing the detailed guidel...
#
#                           Level 2 - Header Level 2 - Body Level 3 - Header  \
# 0  Generation and Control of Documentation            NaN              4.1
# 1  Generation and Control of Documentation            NaN              4.2
#
#                                       Level 3 - Body  Level 4 - Header  \
# 0  All types of document should be defined and ad...               NaN
# 1  Documents should be designed, prepared, review...               NaN
#
#   Level 4 - Body                                               text  \
# 0            NaN  All types of document should be defined and ad...
# 1            NaN  Documents should be designed, prepared, review...
#
#                                               prompt completion category  \
# 0  All types of document should be defined and ad...      other    other
# 1  Documents should be designed, prepared, review...      other    other
#
#    probability
# 0     0.999834
# 1     0.999968

# %%
df1[TARGET].value_counts()
# Out:
#  other      31
#  hygiene     1
# Name: completion, dtype: int64

# %%
df1[PREDICTED].value_counts()
# Out:
#  other      31
#  hygiene     1
# Name: category, dtype: int64

# %%
accuracy_score(df1[TARGET], df1[PREDICTED])
# Out:
# 1.0

# %%
df1[df1[TARGET].isin([" hygiene"])][[TEXT, TARGET, PREDICTED, PROBAB]]
# Out:
#                                                  text completion  category  \
# 28  There should be written policies, procedures, ...    hygiene   hygiene
#
#     probability
# 28     0.688206
