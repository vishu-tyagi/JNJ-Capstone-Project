# %%
import os
from pathlib import Path
import time
import logging
import itertools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from capstone.config import CapstoneConfig
from capstone.data_access import DataClass
from capstone.features import Features
from capstone.evaluation import CustomEvaluation
from capstone.utils.constants import (
    TEXT,
    TARGET,
    ORIGINAL_TEXT,
    SPLIT,
    DEVELOP,
    TEST,
    PREDICTION,
    CORRECTED
)

sns.set_style("darkgrid")
PARENT_PATH = Path(os.getcwd()).parent.absolute()

FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)

# %%
config = CapstoneConfig()
config.CURRENT_PATH = PARENT_PATH

data = DataClass(config)
df = data.build()
df.head(3)
# Out:
#                                                 Text  \
# 0  General Quality System Requirements […] Manage...
# 1  General Quality System Requirements […] Manage...
# 2  General Quality System Requirements […] Manage...
#
#                         Standard mapping?
# 0  [quality management, quality planning]
# 1                    [quality management]
# 2                    [quality management]

# %%
features = Features(config)
df_features = features.build(df)
# Out:
# 2022-12-01 04:22:50,834 - capstone.utils.utils - INFO - func:clean took: 3.05 sec
# 2022-12-01 04:22:51,450 - capstone.utils.utils - INFO - func:fit took: 3.67 sec
# 2022-12-01 04:22:53,098 - capstone.utils.utils - INFO - func:clean took: 1.65 sec
# 2022-12-01 04:22:53,325 - capstone.utils.utils - INFO - func:transform took: 1.87 sec
# 2022-12-01 04:22:53,325 - capstone.utils.utils - INFO - func:fit_transform took: 5.54 sec
# 2022-12-01 04:22:53,510 - capstone.utils.utils - INFO - func:clean took: 0.18 sec
# 2022-12-01 04:22:53,536 - capstone.utils.utils - INFO - func:transform took: 0.21 sec
# 2022-12-01 04:22:53,563 - capstone.utils.utils - INFO - func:build took: 5.79 sec

# %%
dev = df_features[df_features[SPLIT].isin([DEVELOP])].copy()
dev.reset_index(drop=True, inplace=True)
Y_dev = dev[features.mlb.classes_].copy()

test = df_features[df_features[SPLIT].isin([TEST])].copy()
test.reset_index(drop=True, inplace=True)
Y_test = test[features.mlb.classes_].copy()

# %%
bert = pd.read_pickle(os.path.join(data.reports_path, "bert-evaluation.pkl"))
ada = pd.read_pickle(os.path.join(data.reports_path, "ada-evaluation.pkl"))
curie = pd.read_pickle(os.path.join(data.reports_path, "curie-evaluation.pkl"))
davinci = pd.read_pickle(os.path.join(data.reports_path, "davinci-evaluation.pkl"))

bert.reset_index(drop=True, inplace=True)
ada.reset_index(drop=True, inplace=True)
curie.reset_index(drop=True, inplace=True)
davinci.reset_index(drop=True, inplace=True)

# %%
eval = CustomEvaluation()

combined = (bert[PREDICTION] + ada[PREDICTION] + curie[PREDICTION])
combined = combined.apply(eval.majority_vote, minimum_votes=2)
pred = features.mlb.transform(combined)

# %%
eval.compute_sample_wise_metrics(y_true=Y_test.to_numpy(), y_pred=pred)
# Out:
# Hamming Loss    0.011914
# Accuracy        0.752604
# Precision       0.881771
# Recall          0.841611
# F1 Score        0.846606
# F2 Score        0.840392
# dtype: float64

# %%
eval.compute_label_wise_metrics(
    y_true=Y_test.to_numpy(),
    y_pred=pred,
    labels=features.mlb.classes_,
    dev_samples=Y_dev.to_numpy().sum(axis=0).tolist()
)
# Out:
#                                          Precision    Recall  F1 Score  \
# audit inspection                          0.777778  0.777778  0.777778
# calibration                               0.800000  0.666667  0.727273
# capa                                      0.842105  0.800000  0.820513
# change controls                           0.875000  0.777778  0.823529
# clinical research                         0.965517  0.965517  0.965517
# controled substances                      1.000000  0.833333  0.909091
# csv                                       0.000000  0.000000  0.000000
# data management                           0.764706  1.000000  0.866667
# design controls                           1.000000  0.909091  0.952381
# documentation management                  0.818182  0.692308  0.750000
# facilities                                0.884615  0.884615  0.884615
# handling                                  0.777778  0.583333  0.666667
# identification and traceability           1.000000  0.400000  0.571429
# labeling and packaging operations         0.892857  0.961538  0.925926
# laboratory controls                       0.733333  0.785714  0.758621
# material and product controls             0.760000  0.826087  0.791667
# md product cybersecurity                  1.000000  0.750000  0.857143
# medical device post market surveillance   1.000000  0.571429  0.727273
# nc                                        0.842105  0.800000  0.820513
# new product quality planning              1.000000  1.000000  1.000000
# non clinical research                     1.000000  1.000000  1.000000
# packaging operations                      0.500000  0.200000  0.285714
# process & packaging validation            0.625000  0.714286  0.666667
# product returns                           1.000000  0.500000  0.666667
# production process controls               0.976744  0.688525  0.807692
# purchasing controls                       1.000000  0.875000  0.933333
# qrb                                       1.000000  0.833333  0.909091
# qsmr                                      1.000000  0.400000  0.571429
# quality management                        0.850000  0.850000  0.850000
# quality planning                          0.500000  1.000000  0.666667
# rca                                       0.833333  0.750000  0.789474
# risk management                           0.777778  0.608696  0.682927
# samd                                      1.000000  0.666667  0.800000
# stability programs                        0.833333  0.909091  0.869565
# storage and distribution                  0.777778  0.583333  0.666667
# training                                  1.000000  0.705882  0.827586
# udi and serialization                     1.000000  0.600000  0.750000
# utilities and equipment                   0.884615  0.884615  0.884615
# vigilance                                 1.000000  0.857143  0.923077
# vmp                                       1.000000  0.777778  0.875000
#
#                                          F2 Score  Development Samples  \
# audit inspection                         0.777778                   86
# calibration                              0.689655                   78
# capa                                     0.808081                  202
# change controls                          0.795455                   71
# clinical research                        0.965517                  269
# controled substances                     0.862069                   40
# csv                                      0.000000                   37
# data management                          0.942029                  150
# design controls                          0.925926                  132
# documentation management                 0.714286                  117
# facilities                               0.884615                  244
# handling                                 0.614035                   99
# identification and traceability          0.454545                   30
# labeling and packaging operations        0.946970                  223
# laboratory controls                      0.774648                  143
# material and product controls            0.811966                  195
# md product cybersecurity                 0.789474                   37
# medical device post market surveillance  0.625000                   61
# nc                                       0.808081                  202
# new product quality planning             1.000000                   53
# non clinical research                    1.000000                  177
# packaging operations                     0.227273                   59
# process & packaging validation           0.694444                   88
# product returns                          0.555556                   55
# production process controls              0.731707                  441
# purchasing controls                      0.897436                  176
# qrb                                      0.862069                   64
# qsmr                                     0.454545                   33
# quality management                       0.850000                  173
# quality planning                         0.833333                   59
# rca                                      0.765306                  202
# risk management                          0.636364                  180
# samd                                     0.714286                   75
# stability programs                       0.892857                  113
# storage and distribution                 0.614035                   99
# training                                 0.750000                  100
# udi and serialization                    0.652174                   80
# utilities and equipment                  0.884615                  244
# vigilance                                0.882353                   71
# vmp                                      0.813953                   48
#
#                                          Test Samples
# audit inspection                                    9
# calibration                                         6
# capa                                               20
# change controls                                     9
# clinical research                                  29
# controled substances                                6
# csv                                                 3
# data management                                    13
# design controls                                    11
# documentation management                           13
# facilities                                         26
# handling                                           12
# identification and traceability                     5
# labeling and packaging operations                  26
# laboratory controls                                14
# material and product controls                      23
# md product cybersecurity                            4
# medical device post market surveillance             7
# nc                                                 20
# new product quality planning                        2
# non clinical research                              18
# packaging operations                                5
# process & packaging validation                      7
# product returns                                     6
# production process controls                        61
# purchasing controls                                16
# qrb                                                 6
# qsmr                                                5
# quality management                                 20
# quality planning                                    3
# rca                                                20
# risk management                                    23
# samd                                                9
# stability programs                                 11
# storage and distribution                           12
# training                                           17
# udi and serialization                              10
# utilities and equipment                            26
# vigilance                                           7
# vmp                                                 9
