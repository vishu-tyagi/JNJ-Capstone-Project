# %%
import os
from pathlib import Path
import time
import logging
import itertools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import openai

from capstone.config import CapstoneConfig
from capstone.data_access import DataClass
from capstone.features import Features
from capstone.evaluation import CustomEvaluation
from capstone.utils.constants import (
    TEXT,
    TARGET,
    ORIGINAL_TEXT,
    SPLIT,
    DEVELOP,
    TEST
)

sns.set_style("darkgrid")
PARENT_PATH = Path(os.getcwd()).parent.absolute()
openai.api_key = os.getenv("OPENAI_API_KEY")

FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)

# %%
config = CapstoneConfig()
config.CURRENT_PATH = PARENT_PATH

data = DataClass(config)
df = data.build()
df.head(3)
# Out:
#                                                 Text  \
# 0  General Quality System Requirements […] Manage...
# 1  General Quality System Requirements […] Manage...
# 2  General Quality System Requirements […] Manage...
#
#                         Standard mapping?
# 0  [quality management, quality planning]
# 1                    [quality management]
# 2                    [quality management]

# %%
features = Features(config)
df_features = features.build(df)
# Out:
# 2022-11-30 10:59:45,441 - capstone.utils.utils - INFO - func:clean took: 3.14 sec
# 2022-11-30 10:59:46,130 - capstone.utils.utils - INFO - func:fit took: 3.83 sec
# 2022-11-30 10:59:47,894 - capstone.utils.utils - INFO - func:clean took: 1.76 sec
# 2022-11-30 10:59:48,144 - capstone.utils.utils - INFO - func:transform took: 2.01 sec
# 2022-11-30 10:59:48,144 - capstone.utils.utils - INFO - func:fit_transform took: 5.84 sec
# 2022-11-30 10:59:48,337 - capstone.utils.utils - INFO - func:clean took: 0.19 sec
# 2022-11-30 10:59:48,365 - capstone.utils.utils - INFO - func:transform took: 0.22 sec
# 2022-11-30 10:59:48,401 - capstone.utils.utils - INFO - func:build took: 6.12 sec

# %%
labels_to_numeric_map = {
    features.mlb.classes_[i]: i+1 for i in range(len(features.mlb.classes_))
}

labels_to_numeric_map
# Out:
# {'audit inspection': 1,
#  'calibration': 2,
#  'capa': 3,
#  'change controls': 4,
#  'clinical research': 5,
#  'controled substances': 6,
#  'csv': 7,
#  'data management': 8,
#  'design controls': 9,
#  'documentation management': 10,
#  'facilities': 11,
#  'handling': 12,
#  'identification and traceability': 13,
#  'labeling and packaging operations': 14,
#  'laboratory controls': 15,
#  'material and product controls': 16,
#  'md product cybersecurity': 17,
#  'medical device post market surveillance': 18,
#  'nc': 19,
#  'new product quality planning': 20,
#  'non clinical research': 21,
#  'packaging operations': 22,
#  'process & packaging validation': 23,
#  'product returns': 24,
#  'production process controls': 25,
#  'purchasing controls': 26,
#  'qrb': 27,
#  'qsmr': 28,
#  'quality management': 29,
#  'quality planning': 30,
#  'rca': 31,
#  'risk management': 32,
#  'samd': 33,
#  'stability programs': 34,
#  'storage and distribution': 35,
#  'training': 36,
#  'udi and serialization': 37,
#  'utilities and equipment': 38,
#  'vigilance': 39,
#  'vmp': 40}

# %%
numeric_to_labels_map = {}
for label in labels_to_numeric_map:
    numeric_to_labels_map[labels_to_numeric_map[label]] = label

numeric_to_labels_map
# Out:
# {1: 'audit inspection',
#  2: 'calibration',
#  3: 'capa',
#  4: 'change controls',
#  5: 'clinical research',
#  6: 'controled substances',
#  7: 'csv',
#  8: 'data management',
#  9: 'design controls',
#  10: 'documentation management',
#  11: 'facilities',
#  12: 'handling',
#  13: 'identification and traceability',
#  14: 'labeling and packaging operations',
#  15: 'laboratory controls',
#  16: 'material and product controls',
#  17: 'md product cybersecurity',
#  18: 'medical device post market surveillance',
#  19: 'nc',
#  20: 'new product quality planning',
#  21: 'non clinical research',
#  22: 'packaging operations',
#  23: 'process & packaging validation',
#  24: 'product returns',
#  25: 'production process controls',
#  26: 'purchasing controls',
#  27: 'qrb',
#  28: 'qsmr',
#  29: 'quality management',
#  30: 'quality planning',
#  31: 'rca',
#  32: 'risk management',
#  33: 'samd',
#  34: 'stability programs',
#  35: 'storage and distribution',
#  36: 'training',
#  37: 'udi and serialization',
#  38: 'utilities and equipment',
#  39: 'vigilance',
#  40: 'vmp'}

# %%
PROMPT = "prompt"
COMPLETION = "completion"

df_features[PROMPT] = \
    df_features[ORIGINAL_TEXT] \
    .apply(lambda x: f"Text: {x}\n\n###\n\n")

df_features[COMPLETION] = \
    df_features[TARGET] \
    .apply(lambda x: [str(labels_to_numeric_map[y]) for y in x]) \
    .apply(lambda x: ", ".join(x)) \
    .apply(lambda x: f" {x} END")

# %%
dev = df_features[df_features[SPLIT].isin([DEVELOP])].copy()
dev.reset_index(drop=True, inplace=True)
Y_dev = dev[features.mlb.classes_].copy()

test = df_features[df_features[SPLIT].isin([TEST])].copy()
test.reset_index(drop=True, inplace=True)
Y_test = test[features.mlb.classes_].copy()

# %%
# plt.figure(figsize=(6, 3))
fig, ax = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
Y_dev.sum(axis=0).plot.bar(ax=ax[0])
Y_test.sum(axis=0).plot.bar(ax=ax[1])
ax[0].set_title("Development")
ax[1].set_title("Test");

# %%
train, val, _, _ = train_test_split(
    dev, dev[features.mlb.classes_].to_numpy(), test_size=.1, shuffle=True, random_state=128
)
train.reset_index(drop=True, inplace=True)
val.reset_index(drop=True, inplace=True)

Y_train = train[features.mlb.classes_].copy()
Y_val = val[features.mlb.classes_].copy()

# %%
# plt.figure(figsize=(6, 3))
fig, ax = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)
Y_train.sum(axis=0).plot.bar(ax=ax[0])
Y_val.sum(axis=0).plot.bar(ax=ax[1])
ax[0].set_title("Train")
ax[1].set_title("Val");

# %%
train_ft = train[[PROMPT, COMPLETION]].copy()
val_ft = val[[PROMPT, COMPLETION]].copy()

# %%
train_ft.to_json(os.path.join(data.data_path, "ft_training.jsonl"), orient="records", lines=True, force_ascii=False)
val_ft.to_json(os.path.join(data.data_path, "ft_validation.jsonl"), orient="records", lines=True, force_ascii=False)

# %%
MODEL = "ada:ft-columbia-university:multi-label-2022-11-25-02-23-00"

# %%
# function to predict the categories from the test set; input relevant engine name
def get_category(text):
    time.sleep(5)                                               # trottle for rate limit
    response = openai.Completion.create(
            prompt=f"{text}",
            temperature=0,
            top_p=1,
            max_tokens=100,
            stop="END",
            frequency_penalty=0,
            presence_penalty=0,
            model=MODEL,  #"RegulatoryStandardsClassifier2" is the ft-engine in our internal Azure OpenAI, use text-davinci-002 on the free tier. 
            logprobs=2
            #logit_bias={"584":100, "33306":100}
        )
    #return (response["choices"][0])
    return (response["choices"][0]["text"])

# %%
PREDICTION = "prediction"

test[PREDICTION] = test[PROMPT].apply(get_category)
# Out:
# 2022-11-25 12:59:31,614 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25
- openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=70 request_id=0b6b196f492c6bfac51ad135bb0c346f response_code=200
# 2022-11-25 13:29:38,131 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:29:38,281 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=75 request_id=499b9469673d023e290128bd9a9f7347 response_code=200
# 2022-11-25 13:29:43,293 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:29:43,505 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=155 request_id=e834a556948f7cc9d0f5d89d09f378da response_code=200
# 2022-11-25 13:29:48,513 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:29:48,646 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=69 request_id=95e54609e8361440e01dbd54266363e3 response_code=200
# 2022-11-25 13:29:53,657 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:29:53,804 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=84 request_id=44d6e28ff99df53b1126fa5b0597788b response_code=200
# 2022-11-25 13:29:58,817 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:29:58,958 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=76 request_id=a5bc0ddf31ce96d8e42413db3190dcce response_code=200
# 2022-11-25 13:30:03,967 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:04,110 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=80 request_id=84e68e096c3ef52a92dd782af275f2f0 response_code=200
# 2022-11-25 13:30:09,120 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:09,257 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=78 request_id=00f5a4ea4e1829657731ad2d6ce904ba response_code=200
# 2022-11-25 13:30:14,265 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:14,407 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=76 request_id=89305cd7cdca5c9b3a73fce03461855f response_code=200
# 2022-11-25 13:30:19,412 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:19,550 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=73 request_id=f627eab899c8dbd120a29267c59cb6ad response_code=200
# 2022-11-25 13:30:24,555 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:24,712 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=8c3fe4e6b9db258ba7e817d43c2c9e58 response_code=200
# 2022-11-25 13:30:29,715 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:29,943 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=169 request_id=3bfbc4abcf6f1623bbc8c58620488338 response_code=200
# 2022-11-25 13:30:34,948 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:35,084 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=40e36fc3620949167d1b33ac607a88c8 response_code=200
# 2022-11-25 13:30:40,092 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:40,225 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=73 request_id=d7a9909699a32e443a119dceec3c7d56 response_code=200
# 2022-11-25 13:30:45,228 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:45,365 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=73 request_id=19208ebbe95a685ffd98cbdb9c89d61e response_code=200
# 2022-11-25 13:30:50,369 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:50,513 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=70 request_id=fef250fef31dd37cf19cb8085eb857e1 response_code=200
# 2022-11-25 13:30:55,517 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:30:55,647 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=70 request_id=da24822811eb8e00d0bab1521ad6fdc9 response_code=200
# 2022-11-25 13:31:00,652 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:00,788 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=74 request_id=191507fbeedd5849be201f983fa49181 response_code=200
# 2022-11-25 13:31:05,794 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:05,983 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=130 request_id=ba365c817db8a8a8a59cfe270e761b29 response_code=200
# 2022-11-25 13:31:10,990 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:11,137 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=82 request_id=008e7acefbbeec88d3fa85cf2f1ff4ea response_code=200
# 2022-11-25 13:31:16,144 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:16,293 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=70 request_id=e5d561b9fe84ea5622c4ebdb7bd499b7 response_code=200
# 2022-11-25 13:31:21,298 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:21,431 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=8e59b7eb7572962b70b1f03a5a74911d response_code=200
# 2022-11-25 13:31:26,434 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:26,577 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=85 request_id=72ee7ad99d2db8d3dbea816eb421ddf3 response_code=200
# 2022-11-25 13:31:31,581 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:31,803 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=159 request_id=fd10363563404ea8cd4b95962ccb70c2 response_code=200
# 2022-11-25 13:31:36,810 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:36,945 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=76710a16cc75c1a474422ce466b76d13 response_code=200
# 2022-11-25 13:31:41,950 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:42,086 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=a6c0517b5493c0763463139025285331 response_code=200
# 2022-11-25 13:31:47,092 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:47,229 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=72 request_id=1b1a08d011407ed1d4f649202f8fc763 response_code=200
# 2022-11-25 13:31:52,235 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:52,368 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=388e2d426ef65912a40b39997672f8b0 response_code=200
# 2022-11-25 13:31:57,374 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:31:57,507 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=72 request_id=1108a88e97441894ce5fdaead2eaad10 response_code=200
# 2022-11-25 13:32:02,510 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:02,654 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=80 request_id=ca9c3a9c4269e83de69ff80d94ce2d74 response_code=200
# 2022-11-25 13:32:07,660 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:07,796 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=71 request_id=064962a29dbd7d147da7b2e02fd72c83 response_code=200
# 2022-11-25 13:32:12,801 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:12,933 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=69 request_id=cbbf6cd09a2af4eb5c5052303dca31bf response_code=200
# 2022-11-25 13:32:17,938 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:18,125 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=123 request_id=7fe78c63a2673d1e047400b3755a3d65 response_code=200
# 2022-11-25 13:32:23,131 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:23,262 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=68 request_id=f5c5b3bfc3063abf1dfd42fe46bbe7d6 response_code=200
# 2022-11-25 13:32:28,265 - openai - INFO - message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# 2022-11-25 13:32:28,402 - openai - INFO - message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=73 request_id=f3a1c4b4287ab9186c4b54b0b4f45bf2 response_code=200

# %%
test[COMPLETION]
# Out:
# 0              21 END
# 1               5 END
# 2          10, 25 END
# 3              40 END
# 4       3, 19, 31 END
#             ...
# 379            14 END
# 380            25 END
# 381         1, 25 END
# 382             5 END
# 383        11, 38 END
# Name: completion, Length: 384, dtype: object

# %%
CORRECTED = "corrected_prediction"

test[CORRECTED] = \
    test[PREDICTION] \
    .apply(lambda x: x.split(",")) \
    .apply(lambda x: [y.strip() for y in x]) \
    .apply(lambda x: [numeric_to_labels_map[int(y)] for y in x])

# %%
test[CORRECTED]
# Out:
# 0                              [non clinical research]
# 1                                  [clinical research]
# 2      [documentation management, laboratory controls]
# 3                     [process & packaging validation]
# 4                                      [capa, nc, rca]
#                             ...
# 379                [labeling and packaging operations]
# 380                      [production process controls]
# 381                                  [design controls]
# 382                                [clinical research]
# 383              [facilities, utilities and equipment]
# Name: corrected_prediction, Length: 384, dtype: object

# %%
y_pred = features.mlb.transform(test[CORRECTED])

# %%
eval = CustomEvaluation()

# %%
eval.compute_sample_wise_metrics(y_true=Y_test.to_numpy(), y_pred=y_pred)
# Out:
# Hamming Loss    0.015039
# Accuracy        0.721354
# Precision       0.846354
# Recall          0.816174
# F1 Score        0.816694
# F2 Score        0.812894
# dtype: float64

# %%
eval.compute_label_wise_metrics(
    y_true=Y_test.to_numpy(),
    y_pred=y_pred,
    labels=features.mlb.classes_,
    dev_samples=Y_dev.to_numpy().sum(axis=0).tolist()
)
# Out:
#                                          Precision    Recall  F1 Score  \
# audit inspection                          0.857143  0.666667  0.750000
# calibration                               0.800000  0.666667  0.727273
# capa                                      0.800000  0.800000  0.800000
# change controls                           0.777778  0.777778  0.777778
# clinical research                         0.900000  0.931034  0.915254
# controled substances                      1.000000  0.833333  0.909091
# csv                                       0.200000  0.333333  0.250000
# data management                           0.764706  1.000000  0.866667
# design controls                           0.666667  0.909091  0.769231
# documentation management                  0.800000  0.615385  0.695652
# facilities                                0.920000  0.884615  0.901961
# handling                                  0.600000  0.500000  0.545455
# identification and traceability           0.750000  0.600000  0.666667
# labeling and packaging operations         0.923077  0.923077  0.923077
# laboratory controls                       0.600000  0.642857  0.620690
# material and product controls             0.642857  0.782609  0.705882
# md product cybersecurity                  1.000000  0.750000  0.857143
# medical device post market surveillance   1.000000  0.428571  0.600000
# nc                                        0.800000  0.800000  0.800000
# new product quality planning              1.000000  1.000000  1.000000
# non clinical research                     1.000000  0.944444  0.971429
# packaging operations                      0.400000  0.400000  0.400000
# process & packaging validation            0.625000  0.714286  0.666667
# product returns                           1.000000  0.666667  0.800000
# production process controls               0.930233  0.655738  0.769231
# purchasing controls                       0.937500  0.937500  0.937500
# qrb                                       0.833333  0.833333  0.833333
# qsmr                                      0.750000  0.600000  0.666667
# quality management                        0.882353  0.750000  0.810811
# quality planning                          0.500000  1.000000  0.666667
# rca                                       0.800000  0.800000  0.800000
# risk management                           0.647059  0.478261  0.550000
# samd                                      1.000000  0.666667  0.800000
# stability programs                        1.000000  0.818182  0.900000
# storage and distribution                  0.545455  0.500000  0.521739
# training                                  0.916667  0.647059  0.758621
# udi and serialization                     0.750000  0.600000  0.666667
# utilities and equipment                   0.920000  0.884615  0.901961
# vigilance                                 1.000000  0.857143  0.923077
# vmp                                       0.800000  0.444444  0.571429
#
#                                          F2 Score  Development Samples  \
# audit inspection                         0.697674                   86
# calibration                              0.689655                   78
# capa                                     0.800000                  202
# change controls                          0.777778                   71
# clinical research                        0.924658                  269
# controled substances                     0.862069                   40
# csv                                      0.294118                   37
# data management                          0.942029                  150
# design controls                          0.847458                  132
# documentation management                 0.645161                  117
# facilities                               0.891473                  244
# handling                                 0.517241                   99
# identification and traceability          0.625000                   30
# labeling and packaging operations        0.923077                  223
# laboratory controls                      0.633803                  143
# material and product controls            0.750000                  195
# md product cybersecurity                 0.789474                   37
# medical device post market surveillance  0.483871                   61
# nc                                       0.800000                  202
# new product quality planning             1.000000                   53
# non clinical research                    0.955056                  177
# packaging operations                     0.400000                   59
# process & packaging validation           0.694444                   88
# product returns                          0.714286                   55
# production process controls              0.696864                  441
# purchasing controls                      0.937500                  176
# qrb                                      0.833333                   64
# qsmr                                     0.625000                   33
# quality management                       0.773196                  173
# quality planning                         0.833333                   59
# rca                                      0.800000                  202
# risk management                          0.504587                  180
# samd                                     0.714286                   75
# stability programs                       0.849057                  113
# storage and distribution                 0.508475                   99
# training                                 0.687500                  100
# udi and serialization                    0.625000                   80
# utilities and equipment                  0.891473                  244
# vigilance                                0.882353                   71
# vmp                                      0.487805                   48
#
#                                          Test Samples
# audit inspection                                    9
# calibration                                         6
# capa                                               20
# change controls                                     9
# clinical research                                  29
# controled substances                                6
# csv                                                 3
# data management                                    13
# design controls                                    11
# documentation management                           13
# facilities                                         26
# handling                                           12
# identification and traceability                     5
# labeling and packaging operations                  26
# laboratory controls                                14
# material and product controls                      23
# md product cybersecurity                            4
# medical device post market surveillance             7
# nc                                                 20
# new product quality planning                        2
# non clinical research                              18
# packaging operations                                5
# process & packaging validation                      7
# product returns                                     6
# production process controls                        61
# purchasing controls                                16
# qrb                                                 6
# qsmr                                                5
# quality management                                 20
# quality planning                                    3
# rca                                                20
# risk management                                    23
# samd                                                9
# stability programs                                 11
# storage and distribution                           12
# training                                           17
# udi and serialization                              10
# utilities and equipment                            26
# vigilance                                           7
# vmp                                                 9
